# %% [markdown]
# Soumya Khanna PRN: 25070123111
# EXP: 01

# %%
x,y,z="apple","cherry","orange"
print(x,y,z,sep="\n")
# Out:
# apple
# cherry
# orange

# %%
a,b,w,z=2,2.5,"soumya",True
print(type(a),type(b),type(w),type(z),sep="\n")
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
a=10
b=5
print("sum=", a+b)
print("sub=", a-b)
print("mul=", a*b)
print("div=", a/b)
print("exp=", a**b)
# Out:
# sum= 15
# sub= 5
# mul= 50
# div= 2.0
# exp= 100000

# %%
a,b= 12,8
print(a+b, a-b, a*b, a/b, a**b,sep="\n")
# Out:
# 20
# 4
# 96
# 1.5
# 429981696

# %%
a=int(input("enter the value of a="))
b=int(input("enter the value of b="))
print("sum=",a+b,"\n", "sub=",a-b,"\n", "mul=", a*b,"\n", "div=", a/b,"\n", "exp=", a**b,"\n")
# Out:
# enter the value of a=10
# enter the value of b=20
# sum= 30
#  sub= -10
#  mul= 200
#  div= 0.5
#  exp= 100000000000000000000

# %%
a=int(input("enter the value of a="))
b=int(input("enter the value of b="))
print("sum=",a+b, "sub=",a-b, "mul=", a*b, "div=", a/b, "exp=", a**b,sep="\n")
# Out:
# enter the value of a=20
# enter the value of b=10
# sum=
# 30
# sub=
# 10
# mul=
# 200
# div=
# 2.0
# exp=
# 10240000000000

# %%
#To find out the area of circle.
import math
r=float(input("value of r="))
area = math.pi*float(r)**2
print(area)
# Out:
# value of r=10
# 314.1592653589793

# %%
#Calculate the value of log
import math
math.log10(10)
# Out:
# 1.0

# %%
a,b=10,5
if a>b:
  print("b is less than a")
  else:
    print("b is greater than a")
